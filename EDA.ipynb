# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
train_data = pd.read_csv('./data/train.csv')
val_data = pd.read_csv("./data/Track 1/test.csv")

# %%
train_data.head()
# Out:
#    id                    epoch  sat_id             x             y  \
# 0   0  2014-01-01T00:00:00.000       0  -8855.823863  13117.780146
# 1   1  2014-01-01T00:46:43.000       0 -10567.672384   1619.746066
# 2   2  2014-01-01T01:33:26.001       0 -10578.684043 -10180.467460
# 3   3  2014-01-01T02:20:09.001       0  -9148.251857 -20651.437460
# 4   4  2014-01-01T03:06:52.002       0  -6719.092336 -28929.061629
#
#               z        Vx        Vy        Vz         x_sim         y_sim  \
# 0 -20728.353233 -0.908303 -3.808436 -2.022083  -8843.131454  13138.221690
# 1 -24451.813271 -0.302590 -4.272617 -0.612796 -10555.500066   1649.289367
# 2 -24238.280949  0.277435 -4.047522  0.723155 -10571.858472 -10145.939908
# 3 -20720.381279  0.715600 -3.373762  1.722115  -9149.620794 -20618.200201
# 4 -14938.907967  0.992507 -2.519732  2.344703  -6729.358857 -28902.271436
#
#           z_sim    Vx_sim    Vy_sim    Vz_sim
# 0 -20741.615306 -0.907527 -3.804930 -2.024133
# ...

# %%
val_data.head()
# Out:
#      id  sat_id                    epoch         x_sim         y_sim  \
# 0  3927       1  2014-02-01T00:01:45.162 -13366.891347 -14236.753503
# 1  3928       1  2014-02-01T00:22:57.007  -7370.434039 -14498.771520
# 2  3929       1  2014-02-01T00:44:08.852   -572.068654 -13065.289498
# 3  3930       1  2014-02-01T01:05:20.697   6208.945257  -9076.852425
# 4  3931       1  2014-02-01T01:26:32.542  10768.200284  -2199.706707
#
#          z_sim    Vx_sim    Vy_sim    Vz_sim
# 0  6386.774555  4.333815 -0.692764  0.810774
# 1  7130.411325  5.077413  0.360609  0.313402
# 2  7033.794876  5.519106  2.012830 -0.539412
# 3  5548.296900  4.849212  4.338955 -1.869600
# 4  2272.014862  1.940505  6.192887 -3.167724

# %%
train_sats = train_data.sat_id.unique().tolist()
val_sats = val_data.sat_id.unique().tolist()

# %%
any([s not in train_sats for s in val_sats])
# Out:
# False

# %%
plt.plot(train_data[train_data.sat_id == 0].Vx_sim)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pd.read_csv('./data/split_val.csv').head(10)
# Out:
#    Unnamed: 0   id                    epoch  sat_id             x  \
# 0         908  908  2014-01-30T09:25:18.452       0  13728.225602
# 1         909  909  2014-01-30T10:12:01.452       0  11057.804863
# 2         910  910  2014-01-30T10:58:44.453       0   7657.337051
# 3         911  911  2014-01-30T11:45:27.453       0   3631.658532
# 4         912  912  2014-01-30T12:32:10.454       0   -759.985642
# 5         913  913  2014-01-30T13:18:53.454       0  -5028.813393
# 6         914  914  2014-01-30T14:05:36.455       0  -8479.974827
# 7         915  915  2014-01-30T14:52:19.455       0 -10468.052301
# 8         916  916  2014-01-30T15:39:02.456       0 -10747.446116
# 9         917  917  2014-01-30T16:25:45.456       0  -9531.227386
#
#               y             z        Vx        Vy        Vz         x_sim  \
# 0  18250.083743  30979.658387 -0.818415  2.245061 -1.963269   7171.382885
# 1  23948.962609  24630.447890 -1.085993  1.785970 -2.563508   3089.696122
# ...

# %%
dft = pd.read_csv('./data/split_train.csv')
dft = dft[dft.sat_id == 0]
dft.tail(10)
# Out:
#      Unnamed: 0   id                    epoch  sat_id             x  \
# 898         898  898  2014-01-30T01:38:08.447       0   5412.834899
# 899         899  899  2014-01-30T02:24:51.447       0   8383.012529
# 900         900  900  2014-01-30T03:11:34.448       0  11035.773568
# 901         901  901  2014-01-30T03:58:17.448       0  13298.779228
# 902         902  902  2014-01-30T04:45:00.449       0  15111.643991
# 903         903  903  2014-01-30T05:31:43.449       0  16420.892617
# 904         904  904  2014-01-30T06:18:26.450       0  17176.657248
# 905         905  905  2014-01-30T07:05:09.450       0  17330.729421
# 906         906  906  2014-01-30T07:51:52.451       0  16835.982958
# 907         907  907  2014-01-30T08:38:35.451       0  15647.704322
#
#                 y             z        Vx        Vy        Vz         x_sim  \
# 898 -39329.943453  13835.202952  1.106094  0.416143  2.533201  11291.852611
# ...
